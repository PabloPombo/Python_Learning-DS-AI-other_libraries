# %% [markdown]
# # Descriptive and inferential Statistics

# %% [markdown]
# ### Mean

# %%
sample = [1,3,2,5,7,0,2,3]
mean = sum(sample)/len(sample)

print(mean)
# Out:
# 2.875

# %%
#Wheigt mean

sample = [90,80,63,87,77]
weights = [0.20,0.10,0.20,0.40,0.10]

weight_mean = sum(s * w for s,w in zip(sample,weights)) / sum(weights)

print(weight_mean)
# Out:
# 81.10000000000001

# %% [markdown]
# ### Median

# %%
sample = [0,1,14,5,7,9,10]

def median(values):
    ordered = sorted(values)
    print(ordered)
    
    n = len(ordered)
    
    if n%2 == 0:
        return (ordered[int(n/2)] + ordered[int(n/2 +1)]) / 2
    else:
        return (ordered[int(n/2)])
    
median(sample)
# Out:
# [0, 1, 5, 7, 9, 10, 14]
# 7

# %% [markdown]
# ### Mode

# %%
#Number of pets each person owns]
from collections import defaultdict

# %%
sample = [1,3,2,5,7,0,2,3]

def mode(values):
    counts = defaultdict(lambda:0)
    
    for s in values:
        counts[s] += 1
        
    max_count = max(counts.values())
    modes = [v for v in set(values) if counts[v] == max_count]
    return modes

print(mode(sample))
# Out:
# [2, 3]

# %% [markdown]
# ### Variance and Standard Deviation

# %%
#population variance = ((x1-mean)**2 +...+(xn-mean)**2) / N

# %%
data = [0,1,5,7,9,10,14]

def variance(values):
    mean = sum(values) / len(values)
    _variance = sum((v - mean)**2 for v in values) / len (values)
    return _variance

print(variance(data))
# Out:
# 21.387755102040813

# %%
#square root of the variance give us standard deviation. This is the variance scaled into a number expressedin terms of"no. of pets"

# %%
import math 
from math import sqrt
variance(data)
# Out:
# 21.387755102040813

# %%
math.sqrt(variance(data))
# Out:
# 4.624689730353898

# %%
#Sample variance = ((xi-mean)**2 +...+(xn-mean)**2) / (n -1)

# %%
data = [0,1,5,7,9,10,14]

def variance(values, is_sample: bool=False):
    mean = sum(values) / len(values)
    _variance = sum((v - mean)**2 for v in values) / (len (values) - (1 if is_sample else 0))
    return _variance

def std_dev(values, is_sample: bool =False):
    return sqrt(variance(values, is_sample))

print("VARIANCE = {}".format(variance(data, is_sample=True)))
print("STD DEV = {}".format(std_dev(data, is_sample=True)))
# Out:
# VARIANCE = 24.95238095238095
# STD DEV = 4.99523582550223

# %% [markdown]
# ### The Normal Distribution

# %% [markdown]
# #### Probability Density Function (PDF)

# %%
# f(x) = (1 / (std_dev* sqrt(2*pi))) * e**(1/2((x-mu**2)std_dev))

#Defines gow spread out is the distribution

# %%
def normal_pdf(x: float, mean:float, std_dev:float) -> float:
    return(1.0/(2.0 * math.pi * std_dev ** 2) ** 0.5) * math.exp(-1.0 * ((x-mean)**2 / (2.0 * std_dev **2)))

# %% [markdown]
# #### Cumulative Distribution Function (CDF)

# %%
# S-shaped curve (sigmoid curve), projects the area up to that range in the PDF

# %%
from scipy.stats import norm

mean = 64.43
std_dev = 2.99

x = norm.cdf(64.43, mean, std_dev)

print(x)

# 50% of the population
# Out:
# 0.5

# %%
mean = 64.43
std_dev = 2.99

x = norm.cdf(66, mean, std_dev) - norm.cdf(62, mean, std_dev)

print(x)

#Area between 66 and 62 --- 49 % of population
# Out:
# 0.4920450147062894

# %% [markdown]
# #### Inverse CDF

# %%
# Look up a probability and then return the corresponding x-value

# %%
from scipy.stats import norm

x = norm.ppf(0.95, loc=64.43, scale=2.99)

print(x)

# 95% of population in 69
# Out:
# 69.3481123445849

# %%
import random

for i in range (0,1000):
    random_p = random.uniform(0.0, 1.0)
    random_weight = norm.ppf(random_p, loc=64.43, scale=2.99)
    print(random_weight)
# Out:
# 61.15609516905205
# 65.84649867106992
# 66.21320142141057
# 63.16207929408274
# 62.98220868345412
# 65.18567274536716
# 68.94351875364126
# 64.0979990093681
# 63.569305961891345
# 61.11826555300668
# 61.38491962951011
# 62.849758948619474
# 67.60379700116785
# 63.51510543294863
# 68.8130439543527
# 61.356416586089864
# 70.656911839576
# 67.49095639062767
# 64.21562981599682
# 65.77871000138613
# 69.03880589502118
# 59.63970841523408
# 64.09875593330938
# 67.83824786966474
# 69.22199391896628
# 64.05965442365674
# 61.13511675669243
# 64.21364771051873
# 61.3370022797056
# 67.48343362203015
# 65.39771494641418
# 61.606871082088624
# 65.7425126519729
# 66.63584295855529
# 65.35716132281401
# 67.37214793403263
# 66.3930695424511
# 64.75312358249144
# 59.770455464575484
# 66.77935347983392
# 57.88211211611538
# 62.784729605477914
# 61.347854317434916
# 62.81265411989008
# 59.731865795937786
# 62.66628112050052
# 61.05040597724246
# 66.35591952928915
# 66.13928109909247
# 63.165266694855205
# 65.81682479849142
# 63.5033756324086
# 64.4708026856392
# 66.62638459937202
# 66.20570212290068
# 63.49503282769085
# 60.68421074939581
# 59.63744494664877
# 65.34686881402202
# 59.32534958810838
# 65.9401638097717
# 65.53361416995934
# 72.60588745663685
# 67.82802932886523
# 62.44041012258805
# 58.367518093782124
# 60.99888614295367
# 70.7148127490176
# 66.19087314023814
# 63.45055802134334
# 62.55578480454138
# 65.24725617166762
# 66.52133384882403
# 66.91991581957296
# 68.76871902446028
# 68.23639817643021
# 64.7508705455857
# 63.73875707065592
# 63.33332674121095
# 62.50750901600505
# 59.10435145739639
# 65.32652959073368
# 62.60765033969776
# 62.36406027112554
# 65.59309376589981
# 65.66470984660931
# 62.53100520347909
# 66.47661859346918
# 64.26982364855841
# 64.2853696106597
# 65.97266227475683
# 63.421399002921696
# 63.367394931481826
# 67.01751273231139
# 61.380746251791216
# 61.13342305272752
# 64.83256626667432
# 64.33047437122592
# 64.20758019978614
# 62.912422128607375
# 66.30033571310656
# 67.2619979400353
# 58.79688000626565
# 70.40606942591168
# 69.53294514417419
# 61.227491196022434
# 62.59969044774903
# 67.64217611972767
# 60.81425244574485
# 65.17955667774801
# 65.89791319931398
# 61.68821184304111
# 62.27166049384118
# 66.72433003158757
# 63.21977768658408
# 70.43401991170099
# 63.76409346864999
# 64.8851572181892
# 63.46053863048407
# 61.26670446596701
# 65.47377911588714
# 67.30808055573442
# 70.10726338068199
# 62.953050066777394
# 60.935682561494
# 69.25896334932634
# 65.44631924406926
# 66.32518725541797
# 60.588579553659336
# 73.95328115796947
# 67.59857206614022
# 62.690770396808446
# 61.56828633955629
# 64.08840382075276
# 60.82080476702439
# 63.78477390685063
# 68.4175856055076
# 66.07822027802801
# 66.20668000026991
# 65.47646880033562
# 62.39717094991614
# 61.71013348982089
# 67.15913430120145
# 66.43203967073343
# 59.50118336935749
# 64.45884888735984
# 61.74372076292874
# 66.01144893620045
# 64.37879274496326
# 68.1093221871863
# 67.06197361001982
# 64.65538157241222
# 63.35148409500681
# 65.05218757935103
# 60.801253015973046
# 63.76998796022314
# 66.72145526999078
# 61.734087770857066
# 58.33151641722236
# 66.10789367567331
# 67.06732397398281
# 61.4000411788839
# 60.426947343866644
# 67.47535884128847
# 69.93294622431203
# 64.82424663430999
# 63.946669162167915
# 66.81108499746769
# 62.05066775906651
# 69.78899113693284
# 59.377056629727235
# 63.40628160423819
# 62.63813012689377
# 64.5178406373565
# 59.31141287647406
# 61.52031733643838
# 66.2491281096971
# 61.94479836989879
# 64.0704099778002
# 69.25729639085665
# 61.01201125682828
# 68.49013108198943
# 72.30749376330743
# 66.26017650578667
# 61.006521183372016
# 63.497758200102496
# 69.05849155833806
# 66.89011531395505
# 67.03506928207064
# 67.9990634413851
# 64.27913539879073
# 66.90316616706593
# 68.62796169955057
# 62.74058713823064
# 67.95625242898817
# 66.42752662687076
# 65.1838192620277
# 64.36766436397548
# 63.82321453786096
# 62.2188780708209
# 63.06785641422939
# 61.07760347056384
# 60.48826707469559
# 67.03301743503869
# 63.51255122388767
# 64.37401345926853

# %% [markdown]
# #### Z-Scores

# %%
# z = (x - mean) / std_dev
#convert an x-value coming from given distribution with mean and std dev into Z-score

# %%
def z_score(x, mean, std):
    return (x - mean) / std

def z_to_x(z, mean, std):
    return (z * std) + mean

mean = 140000
std_dev = 3000
x = 150000

z = z_score(x, mean, std_dev)
back_to_x = z_to_x(z, mean, std_dev)

print(f"Z-Score: {z}")
print(f"Back to X: {back_to_x}")
# Out:
# Z-Score: 3.3333333333333335
# Back to X: 150000.0

# %%
# Coeficient of variation CV = std_dev / mean

# %% [markdown]
# ### Inferential Statistics

# %% [markdown]
# #### Central Limit Theorem

# %%
#Sample of the uniform distribution will average out to a normal distribution
import random
import plotly.express as px

# %%
sample_size = 31
sample_count = 1000

# %%
#Central Limit Theorem, 1000 samples each with 31
#random numbers between 0.0 an 1.0

x_values = [(sum([random.uniform(0.0, 1.0) for i in range (sample_size)]) / sample_size) for _ in range(sample_count)]

y_values = [1 for _ in range(sample_count)]

px.histogram(x=x_values, y = y_values, nbins=20).show()

#When we groupthem as samples and average them, they form a normal distribution
#sample size greater than 30 means will still roughly form a normal distribution
# Out:
# <div>                            <div id="f17b2e98-75bc-40b7-805e-c0b7f0066335" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("f17b2e98-75bc-40b7-805e-c0b7f0066335")) {                    Plotly.newPlot(                        "f17b2e98-75bc-40b7-805e-c0b7f0066335",                        [{"alignmentgroup":"True","bingroup":"x","histfunc":"sum","hovertemplate":"x=%{x}<br>sum of y=%{y}<extra></extra>","legendgroup":"","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"","nbinsx":20,"offsetgroup":"","orientation":"v","showlegend":false,"x":[0.43974239363468554,0.5538646668324827,0.4879358266421339,0.4810512883235118,0.4246351059844919,0.46742666825214657,0.42455499367893784,0.49555240617309915,0.48147658906906166,0.5099979418485852,0.39332253595848227,0.4987617755388467,0.5033155537669256,0.6103204052199769,0.49539642194689076,0.5115988755587315,0.49822822256215,0.4820180812081904,0.5520811959948492,0.4824813155527436,0.44203844366424844,0.4733719928267734,0.47557693837024256,0.534393679650759,0.45610093170077687,0.5437222977030326,0.4788998309274554,0.5092610203291311,0.42876327410509923,0.512098857533496,0.5075413093386971,0.4245914378681648,0.3955487021843832,0.3965419577759114,0.41184324793533034,0.5167652349641296,0.49199076910527434,0.4749141759307872,0.5157197068953103,0.41912175733112794,0.4253022375917441,0.5087381816658284,0.5329280736636912,0.48964299958989616,0.5244776030985973,0.5148677838773671,0.4756887110658553,0.5340613898116858,0.5074852081249345,0.431543445051568,0.5063728631763187,0.4956583318504914,0.48069082136697183,0.5214650824749909,0.5245022125919445,0.5582223922018498,0.549330495505996,0.38280145530327303,0.5075480566522277,0.5999184410252847,0.5438742818542146,0.5630806955482511,0.5915356241085007,0.45828219076027304,0.5812483298271247,0.5102120783252697,0.6631384932568448,0.4363525400439551,0.45473685210873416,0.4584827303914426,0.596745474299669,0.5418141089507487,0.5913106718764577,0.5118907490870505,0.4783246301798078,0.3847848603568988,0.45679323503398905,0.3467992997683173,0.5398679809320301,0.5182129288686922,0.42695256429475037,0.4455315286198853,0.5221917339741361,0.46316563196619864,0.4969104248397386,0.48912284825562075,0.5558828857469996,0.5602386853905181,0.46655705339451536,0.39923938528029695,0.4000486845381251,0.545646477979694,0.4947592988758236,0.5994797046848955,0.46254393241735897,0.5672971686019557,0.5249810415648628,0.41507002706727525,0.48243314855577785,0.5465802378033356,0.4618502231531026,0.5744191416182569,0.5507723582151987,0.564364666217553,0.46999389480516457,0.4700988801517437,0.5361966742394374,0.5971327265105928,0.47659195634824786,0.518979744697744,0.4675558296408571,0.49132000945801174,0.5285311521642699,0.5574707435546437,0.517419806648185,0.5597008843633368,0.5097389490765869,0.4769683117687864,0.6059967574248155,0.44293403164106404,0.4354723061128011,0.5725366210275594,0.5515951112800284,0.5461149640756164,0.47354880198541943,0.5645105125429252,0.4908430477202067,0.5599806497437979,0.4703860385674947,0.5384243098422052,0.4326374246945089,0.5228430256243107,0.48212252970773267,0.5789500155237117,0.49048197831018464,0.5249249492395266,0.5770316559619741,0.47245536712078573,0.4608508794456944,0.5082492643565664,0.4817302777912542,0.525236012256222,0.45724607354741814,0.5376428281973467,0.5461559039136632,0.5204854589657143,0.5563339664502558,0.5184856635073907,0.5993344909534516,0.4630379394378878,0.47732423739588226,0.38920378145414686,0.5236674762193864,0.47787565924478026,0.5588466247423851,0.5882090256253428,0.5644937074671363,0.5116283274075647,0.6183702612404138,0.3948502913169623,0.49933369707601466,0.5597539314920716,0.45469097837616246,0.44343185369161064,0.4702532447242326,0.4884716026331432,0.5353700367847923,0 ...

# %% [markdown]
# ### Confidence Intervals

# %%
#A range calculation showing how confidently we beleive a sample mean falls in a range for the population mean

# %%
from scipy.stats import norm

# %%
# critical z value capturing 95% of probability at the center of the standar normal distribution

def critical_z_value(p):
    norm_dist = norm(loc=00.0, scale=1.0)
    left_tail_area = (1.0 - p) / 2.0
    upper_area = 1.0 - ((1.0 -p) / 2.0)
    return norm_dist.ppf(left_tail_area), norm_dist.ppf(upper_area)

print(critical_z_value(p=0.95))
# Out:
# (-1.959963984540054, 1.959963984540054)

# %%
#Confidence Interval in Python

#Formula to get this margen: 
# E = -+ zc (sample_std_dev)/sqrt(n)


from math import sqrt
from scipy.stats import norm

# %%
def critical_z_value(p):
    norm_dist = norm(loc=00.0, scale=1.0)
    left_tail_area = (1.0 - p) / 2.0
    upper_area = 1.0 - ((1.0 -p) / 2.0)
    return norm_dist.ppf(left_tail_area), norm_dist.ppf(upper_area)

def confidence_interval(p, sample_mean, sample_std, n):
    #Sample size must be greater than 30
    
    lower, upper = critical_z_value(p)
    lower_ci = lower * (sample_std / sqrt(n))
    upper_ci = upper * (sample_std / sqrt(n))
    
    return sample_mean + lower_ci, sample_mean + upper_ci

print(confidence_interval(p=0.95, sample_mean=64.408, sample_std=2.05, n=31))
# Out:
# (63.68635915701992, 65.12964084298008)

# %% [markdown]
# #### P-Value

# %%
#The probability of something occurring by chance rather than because of a hypothesized explanation
# H0: Null Hypothesis saying that the variable in question had no impact on the experiment and any 
#     positive results are just random luck
# H1: Alternative hypothesis poses that a variable in question (called the controlled variable) is 
#     causing a positive result

# %% [markdown]
# #### Hypothesis Testing

# %%
from scipy.stats import norm

# %%
#Cold has 18 day mean recovery, 1.5 std dev
mean = 18
std_dev = 1.5

#95% probability recovery time takes between 15 and 21 days
x = norm.cdf(21, mean, std_dev) - norm.cdf(15, mean, std_dev)

print(x)
# Out:
# 0.9544997361036416

# %% [markdown]
# #### One-Tailed Test

# %%
# H0: population mean _> 18
# H1: population mean <  18

# %%
#Cold has 18 day mean recovery, 1.5 std dev 
mean = 18
std_dev = 1.5

#What x-value has 5% of area behind it?
x = norm.ppf(0.05, mean, std_dev)

print(x)
# Out:
# 15.53271955957279

# %%
#Cold has 18 day mean recovery, 1.5 std dev 
mean = 18
std_dev = 1.5

#Probability of 16 or lessdays
x = norm.cdf(16, mean, std_dev)

print(x)
# Out:
# 0.09121121972586788

# %%
#p-value of 0.0912 greater than our statistical significance threshold of 0.05 - fail to reject our null hypothesis

# %% [markdown]
# #### Two-Tailed Test

# %%
# H0: population mean = 18
# H1: population mean =! 18

# %%
#Calculating Range of a statistical significance of 5%

#Cold has 18 day mean recovery, 1.5 std dev 
mean = 18
std_dev = 1.5

#What x -value has 2.5% of area behind it
x1 = norm.ppf(0.025, mean, std_dev)

#What x -value has 97.5% of area behind it
x2 = norm.ppf(0.975, mean, std_dev)

print(x1)
print(x2)
# Out:
# 15.060054023189918
# 20.93994597681008

# %%
#Still fail to reject the null hypothesis, the sample mean value for the drug test group is 16, and 16 is not less 
# than 15.06 nor greater than 20.9399

# %%
#Calculating two-tailed p-value

#Cold has 18 day mean recovery, 1.5 std dev 
mean = 18
std_dev = 1.5

#Probability of 16 or less days
p1 = norm.cdf(16, mean, std_dev)

#Probability of 20 or more days
p2 = 1 - norm.cdf(20, mean, std_dev)

#P-value of both tails
p_value = p1+p2
print(p_value)
# Out:
# 0.18242243945173575

# %% [markdown]
# #### T-Distribution

# %%
#fewer than 30 samples
# Is like a normal distribution but has fatter tails to reflect more variance and uncertainity

# %%
from scipy.stats import t

#Get critial value range for 95% confidence with a sample size of 25

n = 25
lower = t.ppf(0.025, df=n-1)
upper = t.ppf(0.975, df=n-1)

print(lower, upper)
# Out:
# -2.063898561628021 2.0638985616280205
